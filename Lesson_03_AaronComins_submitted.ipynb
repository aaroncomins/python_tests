# %% [markdown]
# # Assignment
#
# In this assignment we want to get comfortable with loading and manipulating data in Python. While future assignments will focus more using structured data which we can load into a `DataFrame` using `pandas`, this assignment is focused on semi-structured data and how we can "flatten" it and then load it into other formats. The objective is to see how data flows in Python from one object to another and what advantages and disadvantages each offers.
#
# Let's read the `books.json` data set and display the first item in it.

# %%
import json
with open('../data/books.json', encoding = 'utf-8') as f: # f = file
    books_dict = json.load(f)

from pprint import pprint
pprint(books_dict[0]) # print information for the first book
# Out:
# {'_id': 1,
#  'authors': ['W. Frank Ableson', 'Charlie Collins', 'Robi Sen'],
#  'categories': ['Open Source', 'Mobile'],
#  'isbn': '1933988673',
#  'longDescription': 'Android is an open source mobile phone platform based on '
#                     'the Linux operating system and developed by the Open '
#                     'Handset Alliance, a consortium of over 30 hardware, '
#                     'software and telecom companies that focus on open '
#                     'standards for mobile devices. Led by search giant, '
#                     'Google, Android is designed to deliver a better and more '
#                     'open and cost effective mobile experience.    Unlocking '
#                     "Android: A Developer's Guide provides concise, hands-on "
#                     'instruction for the Android operating system and '
#                     'development tools. This book teaches important '
#                     'architectural concepts in a straightforward writing style '
#                     'and builds on this with practical and useful examples '
#                     'throughout. Based on his mobile development experience '
#                     'and his deep knowledge of the arcane Android technical '
#                     'documentation, the author conveys the know-how you need '
#                     'to develop practical applications that build upon or '
#                     'replace any of Androids features, however small.    '
#                     "Unlocking Android: A Developer's Guide prepares the "
#                     'reader to embrace the platform in easy-to-understand '
#                     'language and builds on this foundation with re-usable '
#                     'Java code examples. It is ideal for corporate and '
#                     'hobbyists alike who have an interest, or a mandate, to '
#                     "deliver software functionality for cell phones.    WHAT'S "
#                     "INSIDE:        * Android's place in the market      * "
#                     'Using the Eclipse environment for Android '
#                     'development      * The Intents - how and why they are '
#                     'used      * Application classes:            o '
#                     'Activity            o Service            o '
#                     'IntentReceiver       * User interface design      * Using '
#                     'the ContentProvider to manage data      * Persisting data '
#                     'with the SQLite database      * Networking examples      '
#                     '* Telephony applications      * Notification methods      '
#                     '* OpenGL, animation & multimedia      * Sample '
#                     'Applications  ',
#  'pageCount': 416,
#  'publishedDate': {'$date': '2009-04-01T00:00:00.000-0700'},
#  'shortDescription': "Unlocking Android: A Developer's Guide provides concise, "
#                      'hands-on instruction for the Android operating system '
#                      'and development tools. This book teaches important '
#                      'architectural concepts in a straightforward writing '
#                      'style and builds on this with practical and useful '
#                      'examples throughout.',
#  'status': 'PUBLISH',
#  'thumbnailUrl': 'https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ.book-thumb-images/ableson.jpg',
#  'title': 'Unlocking Android'}

# %%
print(len(books_dict))
# Out:
# 431

# %% [markdown]
# 1. Write a program that goes through the entire data and extracts the following information:  <span style="color:red" float:right>[4 point]</span>
#
#   - title of the book
#   - name of the first author
#   - name of the second author (if book has more than one author)
#   - number of authors
#   - ISBN
#   - if the word "data" is in the book's description
#   - the number of words in the book's description
#   - the year the book was published
#
#   Of course because JSON data doesn't necessarily enforce any sort of schema, we can't be sure that the information we are trying to extract exists for every book. For example, if the book only has one author, then there is no second author. So use `try` and `except` as you loop through every book and skip to the next item every time some information is missing.
#
#   Store the extracted data in a list named `rows` whose elements are tuples, one tuple per book. For example, the first element of `rows` stores the tuple for the first book and should look like this:
#
#         ('Unlocking Android', 'W. Frank Ableson', 'Charlie Collins', 3, '1933988673', True, 252, 2009)

# %%
from dateutil.parser import parse # For year of publishing

# Empty list to hold tuples
rows = [] 

# Loop through each book in dictionary
for book in books_dict:
    
    # Attempt to extract a title. If no title found, default value is none.
    try:
        title = book['title']
    except:
        title = None
        
    # Attempt to extract first author(0). If first author not found, default value is none.    
    try:
        author_1 = book['authors'][0]
    except:
        author_1 = None
        
    # Attempt to count number of authors. If none found, default value is 0.
    try:
        num_authors = len(book['authors'])
    except:
        num_authors = 0
        
    # If there is more than one author, extract the name of the the second author.
    if num_authors > 1:
        author_2 = book['authors'][1]
    else:
        author_2 = None
    
    # Attempt to extract the ISBN. If not found, default value is none.
    try:
        isbn = book['isbn']
    except:
        isbn = None
        
    # I made an assumption that the word data is in the long description.
    # Attempt to find data in long description. If not found, default value is False.
    try:    
        has_data = True if 'data' in book['longDescription'] else False
    except:
        has_data = False
    
    # I made the assumption that the word is in the long description.
    # Attempt to count the number of words in the description of the book.
    # If an error occurs, default values is none.
    try:
        words = [''.join(c for c in word if c.isaplpha() or c=="'") for word in description[longDescrition].split()]
    # Removing special characters from list of words. If a single character word is not a special character, keep it.   
        desc_len = len(words)
    except:
        desc_len = None
    
    # Attempt to extract the year the book was published. If not found, the default value is none.
    try:
        year_published = parse(book['publishedDate']['$date']).year
    except:
        year_published = None
    
    # Creating a tuple for the book.
    cur_tuple = tuple([title, author_1, author_2, num_authors, isbn, has_data, desc_len, year_published])
    
    # Append the current book's tuple to rows list created earlier.
    rows.append(cur_tuple)

print(len(rows))
pprint(rows)
# Out:
# 431
# [('Unlocking Android',
#   'W. Frank Ableson',
#   'Charlie Collins',
#   3,
#   '1933988673',
#   True,
#   None,
#   2009),
#  ('Android in Action, Second Edition',
#   'W. Frank Ableson',
#   'Robi Sen',
#   2,
#   '1935182722',
#   False,
#   None,
#   2011),
#  ('Specification by Example',
#   'Gojko Adzic',
#   None,
#   1,
#   '1617290084',
#   False,
#   None,
#   2011),
#  ('Flex 3 in Action',
#   'Tariq Ahmed with Jon Hirschi',
#   'Faisal Abid',
#   2,
#   '1933988746',
#   True,
#   None,
#   2009),
#  ('Flex 4 in Action',
#   'Tariq Ahmed',
#   'Dan Orlando',
#   4,
#   '1935182420',
#   True,
#   None,
#   2010),
#  ('Collective Intelligence in Action',
#   'Satnam Alag',
#   None,
#   1,
#   '1933988312',
#   True,
#   None,
#   2008),
#  ('Zend Framework in Action',
#   'Rob Allen',
#   'Nick Lo',
#   3,
#   '1933988320',
#   True,
#   None,
#   2008),
#  ('Flex on Java',
#   'Bernerd Allmon',
#   'Jeremy Anderson',
#   2,
#   '1933988797',
#   True,
#   None,
#   2010),
#  ('Griffon in Action',
#   'Andres Almiray',
#   'Danno Ferrin',
#   4,
#   '1935182234',
#   False,
#   None,
#   2012),
#  ('OSGi in Depth',
#   'Alexandre de Castro Alves',
#   None,
#   1,
#   '193518217X',
#   False,
#   None,
#   2011),
#  ('Flexible Rails', 'Peter Armstrong', None, 1, '1933988509', True, None, 2008),
#  ('Hello! Flex 4', 'Peter Armstrong', None, 1, '1933988762', True, None, 2009),
#  ('Coffeehouse',
#   'Levi Asher',
#   'Christian Crumlish',
#   2,
#   '1884777384',
#   False,
#   None,
#   1997),
#  ('Team Foundation Server 2008 in Action',
#   'Jamil Azher',
#   None,
#   1,
#   '1933988592',
#   True,
#   None,
#   2008),
#  ('Brownfield Application Development in .NET',
#   'Kyle Baley',
#   'Donald Belcham',
#   2,
#   '1933988711',
#   False,
#   None,
#   2010),
#  ('MongoDB in Action', 'Kyle Banker', None, 1, '1935182870', True, None, 2011),
#  ('Distributed Application Development with PowerBuilder 6.0',
#   'Michael J. Barlotta',
#   None,
#   1,
#   '1884777686',
#   False,
#   None,
#   1998),
#  ('Jaguar Development with PowerBuilder 7',
#   'Michael Barlotta',
#   None,
#   1,
#   '1884777864',
#   False,
#   None,
#   1999),
#  ('Taming Jaguar',
#   'Michael J. Barlotta',
#   'Jason R. Weiss',
#   2,
#   '1884777686',
#   True,
#   None,
#   2000),
#  ('3D User Interfaces with Java 3D',
#   'Jon Barrilleaux',
#   None,
#   1,
#   '1884777902',
#   True,
#   None,
#   2000),
#  ('Hibernate in Action',
#   'Christian Bauer',
#   'Gavin King',
#   2,
#   '193239415X',
#   True,
#   None,
#   2004),
#  ('Hibernate in Action (Chinese Edition)',
#   'Christian Bauer',
#   'Gavin King',
#   2,
#   None,
#   False,
#   None,
#   1999),
#  ('Java Persistence with Hibernate',
#   'Christian Bauer',
#   'Gavin King',
#   2,
#   '1932394885',
#   True,
#   None,
#   2006),
#  ('JSTL in Action', 'Shawn Bayern', None, 1, '1930110529', False, None, 2002),
#  ('iBATIS in Action',
#   'Clinton Begin',
#   'Brandon Goodin',
#   3,
#   '1932394826',
#   True,
#   None,
#   2007),
#  ('Designing Hard Software',
#   'Douglas W. Bennett',
#   None,
#   1,
#   '133046192',
#   False,
#   None,
#   1997),
#  ('Hibernate Search in Action',
#   'Emmanuel Bernard',
#   'John Griffin',
#   2,
#   '1933988649',
#   False,
#   None,
#   2008),
#  ('jQuery in Action',
#   'Bear Bibeault',
#   'Yehuda Katz',
#   2,
#   '1933988355',
#   False,
#   None,
#   2008),
#  ('jQuery in Action, Second Edition',
#   'Bear Bibeault',
#   'Yehuda Katz',
#   2,
#   '1935182323',
#   False,
#   None,
#   2010),
#  ('Building Secure and Reliable Network Applications',
#   'Kenneth P. Birman',
#   None,
#   1,
#   '1884777295',
#   False,
#   None,
#   1996),
#  ('Ruby for Rails', 'David A. Black', None, 1, '1932394699', True, None, 2006),
#  ('The Well-Grounded Rubyist',
#   'David A. Black',
#   None,
#   1,
#   '1933988657',
#   False,
#   None,
#   2009),
#  ("Website Owner's Manual",
#   'Paul A. Boag',
#   None,
#   1,
#   '1933988452',
#   False,
#   None,
#   2009),
#  ('ASP.NET 4.0 in Practice',
#   'Daniele Bochicchio',
#   'Stefano Mostarda',
#   4,
#   '1935182463',
#   False,
#   None,
#   2011),
#  ('Hello! Python', 'Anthony Briggs', None, 1, '1935182080', False, None, 2012),
#  ("PFC Programmer's Reference Manual",
#   'Richard Brooks',
#   None,
#   1,
#   '1884777554',
#   False,
#   None,
#   1998),
#  ('Graphics File Formats',
#   'C. Wayne Brown',
#   'Barry J. Shepherd',
#   2,
#   '133034054',
#   True,
#   None,
#   1995),
#  ('Visual Object Oriented Programming',
#   'Margaret M. Burnett',
#   'Adele Goldberg',
#   4,
#   '131723979',
#   False,
#   None,
#   1995),
#  ('iOS in Practice',
#   'Bear P. Cahill',
#   None,
#   1,
#   '1617291269',
#   False,
#   None,
#   2013),
#  ('iPhone in Action',
#   'Christopher Allen',
#   'Shannon Appelcline',
#   2,
#   '193398886X',
#   True,
#   None,
#   2008),
#  ('Silverlight 2 in Action',
#   'Chad A. Campbell',
#   'John Stockton',
#   2,
#   '1933988428',
#   True,
#   None,
#   2008),
#  ('The Quick Python Book, Second Edition',
#   'Naomi R. Ceder',
#   None,
#   1,
#   '193518220X',
#   True,
#   None,
#   2010),
#  ('Internet and Intranet Applications with PowerBuilder 6',
#   'Tom Cervenka',
#   None,
#   1,
#   '1884777600',
#   False,
#   None,
#   2000),
#  ('Practical Methods for Your Year 2000 Problem',
#   'Robert Chapman',
#   None,
#   1,
#   '188477752X',
#   False,
#   None,
#   1998),
#  ('Mobile Agents',
#   'William R. Cockayne and Michael Zyda',
#   'editors',
#   2,
#   '1884777368',
#   False,
#   None,
#   1997),
#  ('Spring Dynamic Modules in Action',
#   'Arnaud Cogoluegnes',
#   'Thierry Templier',
#   4,
#   '1935182307',
#   True,
#   None,
#   2010),
#  ('SQL Server 2008 Administration in Action',
#   'Rod Colledge',
#   None,
#   1,
#   '193398872X',
#   True,
#   None,
#   2009),
#  ('Android in Practice',
#   'Charlie Collins',
#   'Michael D. Galpin',
#   4,
#   '1935182927',
#   True,
#   None,
#   2011),
#  ('Object Oriented Perl',
#   'Damian Conway',
#   None,
#   1,
#   '1884777791',
#   False,
#   None,
#   1999),
#  ('GWT in Practice',
#   'Robert Cooper',
#   'Charles Collins',
#   2,
#   '1933988290',
#   False,
#   None,
#   2008),
#  ('Ajax in Action',
#   'Dave Crane',
#   'Eric Pascarello with Darren James',
#   2,
#   '1932394613',
#   False,
#   None,
#   2005),
#  ('Ajax in Practice',
#   'Dave Crane',
#   'Jord Sonneveld and Bear Bibeault with Ted Goddard',
#   5,
#   '1932394990',
#   False,
#   None,
#   2007),
#  ('Prototype and Scriptaculous in Action',
#   'Dave Crane',
#   'Bear Bibeault with Tom Locke',
#   2,
#   '1933988037',
#   False,
#   None,
#   2007),
#  ('POJOs in Action',
#   'Chris Richardson',
#   None,
#   1,
#   '1932394583',
#   True,
#   None,
#   2006),
#  ('Data Munging with Perl',
#   'David Cross',
#   None,
#   1,
#   '1930110006',
#   True,
#   None,
#   2001),
#  ('Hello! HTML5 & CSS3',
#   'Rob Crowther',
#   None,
#   1,
#   '1935182897',
#   False,
#   None,
#   2012),
#  ('Seam in Action', 'Dan Allen', None, 1, '1933988401', False, None, 2008),
#  ('Wicket in Action',
#   'Martijn Dashorst',
#   'Eelco Hillenius',
#   2,
#   '1932394982',
#   False,
#   None,
#   2008),
#  ('Open Source SOA', 'Jeff Davis', None, 1, '1933988541', False, None, 2009),
#  ('Struts 2 in Action',
#   'Donald Brown',
#   'Chad Michael Davis',
#   4,
#   '193398807X',
#   False,
#   None,
#   2008),
#  ('Essential Guide to Peoplesoft Development and Customization',
#   'Tony DeLia',
#   'Galina Landres',
#   4,
#   '1884777929',
#   False,
#   None,
#   2000),
#  ('.NET Multithreading',
#   'Alan Dennis',
#   None,
#   1,
#   '1930110545',
#   False,
#   None,
#   2002),
#  ('SCWCD Exam Study Kit Second Edition',
#   'Hanumant Deshmukh',
#   'Jignesh Malavia',
#   4,
#   '1932394389',
#   False,
#   None,
#   2005),
#  ('Spring Roo in Action',
#   'Ken Rimple',
#   'Srini Penchikala',
#   2,
#   '193518296X',
#   False,
#   None,
#   2012),
#  ('SOA Governance in Action',
#   'Jos Dirksen',
#   None,
#   1,
#   '1617290270',
#   False,
#   None,
#   2012),
#  ('RSS and Atom in Action',
#   'Dave Johnson',
#   None,
#   1,
#   '1932394494',
#   False,
#   None,
#   2006),
#  ('LDAP Programming, Management and Integration',
#   'Clayton Donley',
#   None,
#   1,
#   '1930110405',
#   True,
#   None,
#   2002),
#  ('Mule in Action',
#   'David Dossot',
#   "John D'Emic",
#   2,
#   '1933988967',
#   True,
#   None,
#   2009),
#  ('Java Foundation Classes',
#   'Stephen C. Drye',
#   'William C. Wake',
#   2,
#   '1884777678',
#   False,
#   None,
#   2001),
#  ('Managing Components with Modeler',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524k-e',
#   False,
#   None,
#   2005),
#  ('Command-line Processing with CLI',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524l-e',
#   False,
#   None,
#   2005),
#  ('Understanding and Using Chain',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524m-e',
#   False,
#   None,
#   2005),
#  ('Working with the Logging and Discovery Components',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524n-e',
#   False,
#   None,
#   2005),
#  ('Uploading files with FileUpload',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524b-e',
#   False,
#   None,
#   2005),
#  ('Handling Protocols with the Net Component',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524c-e',
#   False,
#   None,
#   2005),
#  ('XML Parsing with Digester',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524d-e',
#   False,
#   None,
#   2005),
#  ('JXPath and Betwixt: Working with XML',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524e-e',
#   False,
#   None,
#   2005),
#  ('Validating Data with Validator',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524f-e',
#   False,
#   None,
#   2005),
#  ('Enhancing Java Core Libraries with Collections',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524g-e',
#   False,
#   None,
#   2005),
#  ('Enhancing Java Core Libraries with BeanUtils and Lang',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524h-e',
#   False,
#   None,
#   2005),
#  ('Pool and DBCP: Creating and Using Object Pools',
#   'Vikram Goyal',
#   None,
#   1,
#   '1932394524i-e',
#   False,
#   None,
#   2005),
#  ('Python and Tkinter Programming',
#   'John E. Grayson',
#   None,
#   1,
#   '1884777813',
#   False,
#   None,
#   2000),
#  ('Microsoft.NET for Programmers',
#   'Fergal Grimes',
#   None,
#   1,
#   '1930110197',
#   False,
#   None,
#   2002),
#  ('Grails in Action',
#   'Glen Smith',
#   'Peter Ledbrook',
#   2,
#   '1933988932',
#   False,
#   None,
#   2009),
#  ('Up to Speed with Swing, Second Edition',
#   'Steven Gutz',
#   None,
#   1,
#   '1884777759',
#   False,
#   None,
#   1999),
#  ('OSGi in Action',
#   'Richard S. Hall',
#   'Karl Pauls',
#   5,
#   '1933988916',
#   False,
#   None,
#   2011),
#  ('GWT in Action',
#   'Robert Hanson',
#   'Adam Tacy',
#   2,
#   '1933988231',
#   False,
#   None,
#   2007),
#  ('The Quick Python Book',
#   'Daryl Harms',
#   'Kenneth McDonald',
#   2,
#   '1884777740',
#   True,
#   None,
#   1999),
#  ("SharePoint 2010 Site Owner's Manual",
#   'Yvonne M. Harryman',
#   None,
#   1,
#   '1933988754',
#   False,
#   None,
#   2012),
#  ('Java Development with Ant',
#   'Erik Hatcher',
#   'Steve Loughran',
#   2,
#   '1930110588',
#   False,
#   None,
#   2002),
#  ('Lucene in Action',
#   'Erik Hatcher',
#   'Otis Gospodnetic',
#   2,
#   '1932394281',
#   True,
#   None,
#   2004),
#  ('Lucene in Action, Second Edition',
#   'Erik Hatcher',
#   'Otis Gospodnetic',
#   4,
#   '1933988177',
#   False,
#   None,
#   2010),
#  ('PowerBuilder 6.0 Questions & Answers',
#   'Tim Hatton',
#   None,
#   1,
#   '1884777708',
#   False,
#   None,
#   1998),
#  ('The Awesome Power of PowerJ',
#   'Tim Hatton',
#   None,
#   1,
#   '1884777538',
#   False,
#   None,
#   1998),
#  ('The Awesome Power of Power++',
#   'Tim Hatton',
#   None,
#   1,
#   '1884777546',
#   False,
#   None,
#   1998),
#  ('Azure in Action',
#   'Chris Hay',
#   'Brian H. Prince',
#   2,
#   '193518248X',
#   True,
#   None,
#   2010),
#  ('Distributed Agile in Action',
#   'Vikas Hazrati',
#   'Balaji D Loganathan',
#   2,
#   '1935182412',
#   False,
#   None,
#   None),
#  ('Metaprogramming in .NET',
#   'Kevin Hazzard',
#   'Jason Bock',
#   2,
#   '1617290262',
#   False,
#   None,
#   2012),
#  ('Portlets and Apache Portals',
#   'Stefan Hepper',
#   'Peter Fischer',
#   5,
#   None,
#   True,
#   None,
#   2005),
#  ('Code Generation in Action',
#   'Jack Herrington',
#   None,
#   1,
#   '1930110979',
#   True,
#   None,
#   2003),
#  ('Illustrated Guide to HTTP',
#   'Paul S. Hethmon',
#   None,
#   1,
#   '138582262',
#   False,
#   None,
#   1997),
#  ('Agile ALM', 'Michael Hüttermann', None, 1, '1935182633', False, None, 2011),
#  ('Java Network Programming, Second Edition',
#   'Merlin Hughes',
#   'Michael Shoffner',
#   4,
#   '188477749X',
#   False,
#   None,
#   1999),
#  ('Struts in Action',
#   'Ted N. Husted',
#   'Cedric Dumoulin',
#   4,
#   '1932394249',
#   True,
#   None,
#   2002),
#  ('Camel in Action',
#   'Claus Ibsen',
#   'Jonathan Anstey',
#   2,
#   '1935182366',
#   False,
#   None,
#   2011),
#  ('Taming Text',
#   'Grant S. Ingersoll',
#   'Thomas S. Morton',
#   4,
#   '193398838X',
#   True,
#   None,
#   2012),
#  ('JBoss in Action',
#   'Javid Jamae',
#   'Peter Johnson',
#   2,
#   '1933988029',
#   False,
#   None,
#   2009),
#  ('Gnuplot in Action',
#   'Philipp K. Janert',
#   None,
#   1,
#   '1933988398',
#   True,
#   None,
#   2009),
#  ('Extending and Embedding Perl',
#   'Tim Jenness',
#   'Simon Cozens',
#   2,
#   '1930110820',
#   False,
#   None,
#   2002),
#  ('iOS 4 in Action',
#   'Jocelyn Harrington',
#   'Brandon Trebitowski',
#   5,
#   '1617290017',
#   False,
#   None,
#   2011),
#  ('Elements of Programming with Perl',
#   'Andrew L. Johnson',
#   None,
#   1,
#   '1884777805',
#   True,
#   None,
#   1999),
#  ('Learn Windows PowerShell in a Month of Lunches',
#   'Don Jones',
#   None,
#   1,
#   '1617290211',
#   False,
#   None,
#   2011),
#  ('R in Action', 'Robert I. Kabacoff', None, 1, '1935182390', True, None, 2011),
#  ('Android in Practice',
#   'Matthias Kaeppler',
#   'Michael D. Galpin',
#   3,
#   '9781935182924',
#   False,
#   None,
#   None),
#  ('SOA Security',
#   'Ramarao Kanneganti',
#   'Prasad A. Chodavarapu',
#   2,
#   '1932394680',
#   False,
#   None,
#   2007),
#  ('Rails 3 in Action',
#   'Ryan Bigg',
#   'Yehuda Katz',
#   2,
#   '1935182277',
#   False,
#   None,
#   2011),
#  ('Continuous Integration in .NET',
#   'Marcin Kawalerowicz',
#   'Craig Berntson',
#   2,
#   '1935182552',
#   False,
#   None,
#   2011),
#  ('Technology Paradise Lost',
#   'Erik Keller',
#   None,
#   1,
#   '1932394133',
#   False,
#   None,
#   2004),
#  ('Kermit 95+',
#   'Kermit Project at Columbia University',
#   None,
#   1,
#   '1930110057',
#   False,
#   None,
#   2003),
#  ('Laszlo in Action',
#   'Norman Klein',
#   'Max Carlson with Glenn MacEwen',
#   2,
#   '1932394834',
#   False,
#   None,
#   2008),
#  ('Groovy in Action',
#   'Dierk Koenig with Andrew Glover',
#   'Paul King',
#   4,
#   '1932394842',
#   True,
#   None,
#   2007),
#  ('Groovy in Action, Second Edition',
#   'Dierk König',
#   'Guillaume Laforge',
#   8,
#   '1935182447',
#   True,
#   None,
#   None),
#  ('Object Technology Centers of Excellence',
#   'Timothy D. Korson',
#   'Vijay K. Vaishnavi',
#   2,
#   '132612313',
#   False,
#   None,
#   1996),
#  ('Test Driven', 'Lasse Koskela', None, 1, '1932394850', False, None, 2007),
#  ('Effective Unit Testing',
#   'Lasse Koskela',
#   None,
#   1,
#   '1935182579',
#   False,
#   None,
#   2013),
#  ('Making Java Groovy',
#   'Kenneth A. Kousen',
#   None,
#   1,
#   '1935182943',
#   True,
#   None,
#   2013),
#  ('The Awesome Power of Direct3D/DirectX',
#   'Peter J. Kovach',
#   None,
#   1,
#   '1884777473',
#   False,
#   None,
#   2002),
#  ('Practical Software Requirements',
#   'Benjamin L. Kovitz',
#   None,
#   1,
#   '1884777597',
#   False,
#   None,
#   1998),
#  ('NHibernate in Action',
#   'Pierre Henri Kuate',
#   'Tobin Harris',
#   5,
#   '1932394923',
#   True,
#   None,
#   2009),
#  ('Microsoft Reporting Services in Action',
#   'Teo Lachev',
#   None,
#   1,
#   '1932394222',
#   False,
#   None,
#   2004),
#  ('AspectJ in Action',
#   'Ramnivas Laddad',
#   None,
#   1,
#   '1930110936',
#   False,
#   None,
#   2003),
#  ('AspectJ in Action, Second Edition',
#   'Ramnivas Laddad',
#   None,
#   1,
#   '1933988053',
#   False,
#   None,
#   2009),
#  ('Hadoop in Action', 'Chuck Lam', None, 1, '1935182196', True, None, 2010),
#  ('SQR in PeopleSoft and Other Applications',
#   'Galina',
#   'Vlad Landres',
#   2,
#   '1884777775',
#   False,
#   None,
#   2003),
#  ('SQR in PeopleSoft and Other Applications, Second Edition',
#   'Galina Landres',
#   'Vlad Landres',
#   2,
#   '1932394001',
#   True,
#   None,
#   2003),
#  ('F# in Action', 'Amanda Laucher', None, 1, '1935182250', False, None, None),
#  ('Tuscany SCA in Action',
#   'Simon Laws',
#   'Mark Combellack',
#   5,
#   '1933988894',
#   True,
#   None,
#   2011),
#  ('Client/Server Yellow Pages',
#   'Compiled',
#   'introduced by Ted Lewis',
#   2,
#   '1884777082',
#   False,
#   None,
#   1995),
#  ('Object Oriented Application Frameworks',
#   'Ted Lewis',
#   'friends',
#   2,
#   '1884777066',
#   False,
#   None,
#   1995),
#  ('Tapestry in Action',
#   'Howard M. Lewis Ship',
#   None,
#   1,
#   '1932394117',
#   False,
#   None,
#   2004),
#  ('WebWork in Action',
#   'Patrick Lightbody',
#   'Jason Carreira',
#   2,
#   '1932394532',
#   False,
#   None,
#   2005),
#  ('MacRuby in Action',
#   'Brendan G. Lim with Jerry Cheung',
#   'Jeremy McAnally',
#   2,
#   '1935182498',
#   False,
#   None,
#   2012),
#  ('Erlang and OTP in Action',
#   'Martin Logan',
#   'Eric Merritt',
#   4,
#   '1933988789',
#   False,
#   None,
#   2010),
#  ("SharePoint 2007 Developer's Guide to Business Data Catalog",
#   'Brett Lonsdale',
#   'Nick Swan',
#   2,
#   '1933988819',
#   True,
#   None,
#   2009),
#  ('Doing IT Right', 'Harold Lorin', None, 1, '133964256', False, None, 1995),
#  ('Adobe AIR in Action',
#   'Joey Lott',
#   'Kathryn Rotondo',
#   4,
#   '1933988487',
#   False,
#   None,
#   2008),
#  ('Ant in Action',
#   'Steve Loughran',
#   'Erik Hatcher',
#   2,
#   '193239480X',
#   True,
#   None,
#   2007),
#  ('Restlet in Action',
#   'Jerome Louvel',
#   'Thierry Boileau',
#   4,
#   '193518234X',
#   False,
#   None,
#   2012),
#  ('iText in Action', 'Bruno Lowagie', None, 1, '1932394796', False, None, 2006),
#  ('iText in Action, Second Edition',
#   'Bruno Lowagie',
#   None,
#   1,
#   '1935182617',
#   True,
#   None,
#   2010),
#  ('Power-3D', 'Kyle Lussier', None, 1, '138412146', False, None, 1997),
#  ('SNA and TCP/IP Enterprise Networking',
#   'Daniel C. Lynch',
#   'James P. Gray',
#   4,
#   '131271687',
#   False,
#   None,
#   1997),
#  ('Subversion in Action',
#   'Jeffrey Machols',
#   None,
#   1,
#   '1932394478',
#   False,
#   None,
#   2004),
#  ('Minimal Perl', 'Tim Maher', None, 1, '1932394508', False, None, 2006),
#  ('Distributed Programming with Java',
#   'Qusay H. Mahmoud',
#   None,
#   1,
#   '1884777651',
#   False,
#   None,
#   1999),
#  ('Comprehensive Networking Glossary and Acronym Guide',
#   'Gary Scott Malkin',
#   None,
#   1,
#   '013319955X',
#   False,
#   None,
#   1995),
#  ('JavaServer Faces in Action',
#   'Kito D. Mann',
#   None,
#   1,
#   '1932394125',
#   True,
#   None,
#   2004),
#  ('LINQ in Action',
#   'Fabrice Marguerie',
#   'Steve Eichert',
#   3,
#   '1933988169',
#   True,
#   None,
#   2008),
#  ('Internet BBSs',
#   'Richard Scott Mark',
#   None,
#   1,
#   '132869985',
#   False,
#   None,
#   1996),
#  ('Algorithms of the Intelligent Web',
#   'Haralambos Marmanis',
#   'Dmitry Babenko',
#   2,
#   '1933988665',
#   True,
#   None,
#   2009),
#  ('JUnit in Action',
#   'Vincent Massol with Ted Husted',
#   None,
#   1,
#   '1930110995',
#   True,
#   None,
#   2003),
#  ('Tika in Action',
#   'Chris A. Mattmann',
#   'Jukka L. Zitting',
#   2,
#   '1935182854',
#   False,
#   None,
#   2011),
#  ('Ruby in Practice',
#   'Jeremy McAnally',
#   'Assaf Arkin',
#   2,
#   '1933988479',
#   True,
#   None,
#   2009),
#  ('Inside LotusScript', 'Joe McGinn', None, 1, '1884777481', False, None, 1997),
#  ('Maximum MIDI', 'Paul Messick', None, 1, '1884777449', False, None, 1997),
#  ('Planning and Managing ATM Networks',
#   'Daniel Minoli',
#   'Thomas W. Golway',
#   4,
#   '132621894',
#   False,
#   None,
#   1997),
#  ('Client/Server Applications on ATM Networks',
#   'Daniel Minoli',
#   'Andrew Schmidt',
#   2,
#   '137353006',
#   True,
#   None,
#   1997),
#  ('JavaFX in Action', 'Simon Morris', None, 1, '1933988991', False, None, 2009),
#  ('Entity Framework 4 in Action',
#   'Stefano Mostarda',
#   'Marco De Sanctis',
#   4,
#   '1935182188',
#   True,
#   None,
#   2011),
#  ('ASP.NET 2.0 Web Parts in Action',
#   'Darren Neimke',
#   None,
#   1,
#   '193239477X',
#   False,
#   None,
#   2006),
#  ('Sass and Compass in Action',
#   'Wynn Netherland',
#   'Nathan Weizenbaum',
#   5,
#   '1617290149',
#   False,
#   None,
#   2013),
#  ('Core OWL 5.0', 'Ted Neward', None, 1, '1884777503', False, None, 1997),
#  ('Advanced OWL 5.0', 'Ted Neward', None, 1, '1884777465', False, None, 1998),
#  ('Server-Based Java Programming',
#   'Ted Neward',
#   None,
#   1,
#   '1884777716',
#   False,
#   None,
#   2000),
#  ('SQL Server MVP Deep Dives',
#   'Contributions from 53 SQL Server MVPs',
#   'Edited by Paul Nielsen',
#   8,
#   '1935182048',
#   True,
#   None,
#   2009),
#  ('SQL Server MVP Deep Dives',
#   'Contributions from 53 SQL Server MVPs; Edited by Paul Nielsen',
#   'Kalen Delaney',
#   7,
#   '9781935182047',
#   True,
#   None,
#   2009),
#  ('SQL Server MVP Deep Dives',
#   'Paul Nielsen',
#   'Kalen Delaney',
#   7,
#   '9781935182047',
#   False,
#   None,
#   2009),
#  ('PostGIS in Action',
#   'Regina O. Obe',
#   'Leo S. Hsu',
#   2,
#   '1935182269',
#   True,
#   None,
#   2011),
#  ('Programming Mac OS X',
#   "Kevin O'Malley",
#   None,
#   1,
#   '1930110855',
#   False,
#   None,
#   2003),
#  ('The Art of Unit Testing',
#   'Roy Osherove',
#   None,
#   1,
#   '1933988274',
#   True,
#   None,
#   2009),
#  ('Mahout in Action',
#   'Sean Owen',
#   'Robin Anil',
#   5,
#   '1935182684',
#   False,
#   None,
#   2011),
#  ('ASP.NET MVC in Action',
#   'Jeffrey Palermo',
#   'Ben Scheirman',
#   4,
#   '1933988622',
#   False,
#   None,
#   2009),
#  ('ASP.NET MVC 2 in Action',
#   'Jeffrey Palermo',
#   'Ben Scheirman',
#   6,
#   '193518279X',
#   True,
#   None,
#   2010),
#  ('ASP.NET MVC 4 in Action',
#   'Jeffrey Palermo',
#   'Jimmy Bogard',
#   6,
#   '1617290416',
#   True,
#   None,
#   2012),
#  ('EJB 3 in Action',
#   'Debu Panda',
#   'Reza Rahman',
#   3,
#   '1933988347',
#   False,
#   None,
#   2007),
#  ('EJB 3 in Action, Second Edition',
#   'Debu Panda',
#   'Reza Rahman',
#   5,
#   '1935182994',
#   False,
#   None,
#   2014),
#  ("Explorer's Guide to the Semantic Web",
#   'Thomas B. Passin',
#   None,
#   1,
#   '1932394206',
#   True,
#   None,
#   2004),
#  ('Practical LotusScript',
#   'Anthony Patton',
#   None,
#   1,
#   '1884777767',
#   False,
#   None,
#   1999),
#  ('Domino Development with Java',
#   'Anthony Patton',
#   None,
#   1,
#   '1930110049',
#   False,
#   None,
#   2000),
#  ('Windows PowerShell in Action',
#   'Bruce Payette',
#   None,
#   1,
#   '1932394907',
#   False,
#   None,
#   2007),
#  ('Windows PowerShell in Action, Second Edition',
#   'Bruce Payette',
#   None,
#   1,
#   '1935182137',
#   False,
#   None,
#   2011),
#  ('Silverlight 4 in Action, Revised Edition',
#   'Pete Brown',
#   None,
#   1,
#   '1935182374',
#   True,
#   None,
#   2010),
#  ('Silverlight 5 in Action',
#   'Pete Brown',
#   None,
#   1,
#   '1617290319',
#   False,
#   None,
#   2012),
#  ('Hibernate Quickly',
#   'Patrick Peak',
#   'Nick Heudecker',
#   2,
#   '1932394419',
#   True,
#   None,
#   2005),
#  ('Generative Art', 'Matt Pearson', None, 1, '1935182625', False, None, 2011),
#  ('Windows Phone 7 in Action',
#   'Timothy Binkley-Jones',
#   'Massimo Perga',
#   4,
#   '1617290092',
#   False,
#   None,
#   2012),
#  ('Lift in Action',
#   'Timothy Perrett',
#   None,
#   1,
#   '1935182803',
#   False,
#   None,
#   2011),
#  ('Web Development with Apache and Perl',
#   'Theo Petersen',
#   None,
#   1,
#   '1930110065',
#   True,
#   None,
#   2002),
#  ('Real-World Functional Programming',
#   'Tomas Petricek with Jon Skeet',
#   None,
#   1,
#   '1933988924',
#   False,
#   None,
#   2009),
#  ('Machine Learning in Action',
#   'Peter Harrington',
#   None,
#   1,
#   '1617290181',
#   True,
#   None,
#   2012),
#  ('Dependency Injection',
#   'Dhanji R. Prasanna',
#   None,
#   1,
#   '193398855X',
#   False,
#   None,
#   2009),
#  ('Understanding Enterprise SOA',
#   'Eric Pulier and Hugh Taylor',
#   'Foreword by Paul Gaffney',
#   2,
#   '1932394591',
#   False,
#   None,
#   2005),
#  ('Open-Source ESBs in Action',
#   'Tijs Rademakers',
#   'Jos Dirksen',
#   2,
#   '1933988215',
#   False,
#   None,
#   2008),
#  ('Activiti in Action',
#   'Tijs Rademakers',
#   None,
#   1,
#   '1617290122',
#   False,
#   None,
#   2012),
#  ('DSLs in Boo: Domain-Specific Languages in .NET',
#   'Oren Eini writing as Ayende Rahien',
#   None,
#   1,
#   '1933988606',
#   False,
#   None,
#   2010),
#  ('JUnit Recipes',
#   'J. B. Rainsberger with contributions by Scott Stirling',
#   None,
#   1,
#   '1932394230',
#   True,
#   None,
#   2004),
#  ('wxPython in Action',
#   'Noel Rappin',
#   'Robin Dunn',
#   2,
#   '1932394621',
#   False,
#   None,
#   2006),
#  ('Clojure in Action',
#   'Amit Rathore',
#   None,
#   1,
#   '1935182595',
#   False,
#   None,
#   2011),
#  ('Scala in Action',
#   'Nilanjan Raychaudhuri',
#   None,
#   1,
#   '1935182757',
#   False,
#   None,
#   2013),
#  ('Working with Objects',
#   'Trygve Reenskaug',
#   None,
#   1,
#   '134529308',
#   True,
#   None,
#   1995),
#  ('PHP in Action',
#   'Dagfinn Reiersøl with Marcus Baker',
#   'Chris Shiflett',
#   2,
#   '1932394753',
#   False,
#   None,
#   2007),
#  ('Secrets of the JavaScript Ninja',
#   'John Resig',
#   None,
#   1,
#   '193398869X',
#   False,
#   None,
#   2012),
#  ('Microsoft Office Essentials',
#   'Ronny Richardson',
#   None,
#   1,
#   '132623129',
#   True,
#   None,
#   1996),
#  ('Swing',
#   'Matthew Robinson',
#   'Pavel Vorobiev',
#   2,
#   '1884777848',
#   False,
#   None,
#   1999),
#  ('Swing Second Edition', None, None, 0, '193011088X', False, None, 2003),
#  ('The Awesome Power of Java Beans',
#   'Lawrence H. Rodrigues',
#   None,
#   1,
#   '1884777562',
#   False,
#   None,
#   1998),
#  ('Personal Videoconferencing',
#   'Evan Rosen',
#   None,
#   1,
#   '013268327X',
#   False,
#   None,
#   1996),
#  ('The Cloud at Your Service',
#   'Jothy Rosenberg',
#   'Arthur Mateos',
#   2,
#   '1935182528',
#   False,
#   None,
#   2010),
#  ('Implementing Elliptic Curve Cryptography',
#   'Michael Rosing',
#   None,
#   1,
#   '1884777694',
#   False,
#   None,
#   1998),
#  ('SOA Patterns',
#   'Arnon Rotem-Gal-Oz',
#   None,
#   1,
#   '1933988266',
#   True,
#   None,
#   2012),
#  ('Hello World!',
#   'Warren D. Sande',
#   'Carter Sande',
#   2,
#   '1933988495',
#   False,
#   None,
#   2009),
#  ('SCBCD Exam Study Kit',
#   'Paul Sanghera',
#   None,
#   1,
#   '1932394400',
#   False,
#   None,
#   2005),
#  ('Portlets in Action',
#   'Ashish Sarin',
#   None,
#   1,
#   '1935182544',
#   False,
#   None,
#   2011),
#  ('SWT/JFace in Action',
#   'Matthew Scarpino',
#   'Stephen Holder',
#   5,
#   '1932394273',
#   False,
#   None,
#   2004),
#  ('OpenCL in Action',
#   'Matthew Scarpino',
#   None,
#   1,
#   '1617290173',
#   False,
#   None,
#   2011),
#  ('Multiprotocol over ATM',
#   'Andrew Schmidt',
#   'Daniel Minoli',
#   2,
#   '138892709',
#   False,
#   None,
#   1998),
#  ('Dependency Injection in .NET',
#   'Mark Seemann',
#   None,
#   1,
#   '1935182501',
#   False,
#   None,
#   2011),
#  ('Java 3D Programming',
#   'Daniel Selman',
#   None,
#   1,
#   '1930110359',
#   False,
#   None,
#   2002),
#  ('Liferay in Action',
#   'Richard Sezov',
#   'Jr',
#   2,
#   '193518282X',
#   False,
#   None,
#   2011),
#  ('JSP Tag Libraries',
#   'Gal Shachor',
#   'Adam Chace',
#   3,
#   '193011009X',
#   True,
#   None,
#   2001),
#  ('Instant Messaging in Java',
#   'Iain Shigeoka',
#   None,
#   1,
#   '1930110464',
#   True,
#   None,
#   2002),
#  ('Java Applets and Channels Without Programming',
#   'Ronny Richardson',
#   'Michael Shoffner',
#   6,
#   '1884777392',
#   False,
#   None,
#   1999),
#  ('PowerShell in Practice',
#   'Richard Siddaway',
#   None,
#   1,
#   '1935182005',
#   False,
#   None,
#   2010),
#  ('PowerShell and WMI',
#   'Richard Siddaway',
#   None,
#   1,
#   '1617290114',
#   False,
#   None,
#   2012),
#  ('Making Sense of Java',
#   'Bruce Simpson',
#   'John Mitchell',
#   6,
#   '132632942',
#   False,
#   None,
#   1996),
#  ('C++/CLI in Action',
#   'Nishant Sivakumar',
#   None,
#   1,
#   '1932394818',
#   False,
#   None,
#   2007),
#  ('C# in Depth', 'Jon Skeet', None, 1, '1933988363', True, None, 2008),
#  ('C# in Depth, Second Edition',
#   'Jon Skeet',
#   None,
#   1,
#   '1935182471',
#   False,
#   None,
#   None),
#  ('Magical A-Life Avatars',
#   'Peter Small',
#   None,
#   1,
#   '1884777589',
#   False,
#   None,
#   2000),
#  ('Becoming Agile',
#   'Greg Smith',
#   'Ahmed Sidky',
#   2,
#   '1933988258',
#   False,
#   None,
#   2009),
#  ('ActiveMQ in Action',
#   'Bruce Snyder',
#   'Dejan Bosanac',
#   4,
#   '1933988940',
#   False,
#   None,
#   2011),
#  ('Implementing PeopleSoft Financials',
#   'Early Stephens',
#   None,
#   1,
#   '138411808',
#   False,
#   None,
#   1997),
#  ('SQL Server DMVs in Action',
#   'Ian W. Stirk',
#   None,
#   1,
#   '1935182730',
#   True,
#   None,
#   2011),
#  ('Scala in Depth',
#   'Joshua D. Suereth',
#   None,
#   1,
#   '1935182706',
#   False,
#   None,
#   2012),
#  ('JMX in Action',
#   'Benjamin G. Sullins',
#   'Mark B. Whipple',
#   2,
#   '1930110561',
#   False,
#   None,
#   2002),
#  ('EJB Cookbook',
#   'Benjamin G. Sullins',
#   'Mark B. Whipple',
#   2,
#   '1930110944',
#   False,
#   None,
#   2003),
#  ('GWT in Action, Second Edition',
#   'Adam Tacy',
#   'Robert Hanson',
#   5,
#   '1935182846',
#   False,
#   None,
#   2013),
#  ('JUnit in Action, Second Edition',
#   'Petar Tahchiev',
#   'Felipe Leme',
#   5,
#   '1935182021',
#   True,
#   None,
#   2010),
#  ('Bitter Java', 'Bruce A. Tate', None, 1, '193011043X', False, None, 2002),
#  ('Bitter EJB', 'Bruce Tate', 'Mike Clark', 4, '1930110952', False, None, 2003),
#  ('Spring Batch in Action',
#   'Arnaud Cogoluegnes',
#   'Thierry Templier',
#   4,
#   '1935182951',
#   False,
#   None,
#   2011),
#  ('JDK 1.4 Tutorial',
#   'Gregory M. Travis',
#   None,
#   1,
#   '1930110456',
#   False,
#   None,
#   2002),
#  ('iPhone and iPad in Action',
#   'Brandon Trebitowski',
#   'Christopher Allen',
#   4,
#   '1935182587',
#   False,
#   None,
#   2010),
#  ('SQL Server 2005 Reporting Services in Action',
#   'Bret Updegraff',
#   None,
#   1,
#   '1932394761',
#   True,
#   None,
#   2006),
#  ('Ten Years of UserFriendly.Org',
#   'JD "Illiad" Frazer',
#   None,
#   1,
#   '1935182129',
#   False,
#   None,
#   2008),
#  ('Graphics Programming with Perl',
#   'Martien Verbruggen',
#   None,
#   1,
#   '1930110022',
#   False,
#   None,
#   2002),
#  ('RabbitMQ in Action',
#   'Alvaro Videla',
#   'Jason J.W. Williams',
#   2,
#   '1935182978',
#   False,
#   None,
#   2012),
#  ('XDoclet in Action',
#   'Craig Walls',
#   'Norman Richards',
#   2,
#   '1932394052',
#   True,
#   None,
#   2003),
#  ('Spring in Action',
#   'Craig Walls',
#   'Ryan Breidenbach',
#   2,
#   '1932394354',
#   False,
#   None,
#   2005),
#  ('Spring in Action, Second Edition',
#   'Craig Walls with Ryan Breidenbach',
#   None,
#   1,
#   '1933988134',
#   False,
#   None,
#   2007),
#  ('Spring in Action, Third Edition',
#   'Craig Walls',
#   None,
#   1,
#   '1935182358',
#   False,
#   None,
#   2011),
#  ('Spring in Practice',
#   'Willie Wheeler with Joshua White',
#   None,
#   1,
#   '1935182056',
#   False,
#   None,
#   2013),
#  ('Java 2 Micro Edition',
#   'James P. White',
#   'David A. Hemphill',
#   2,
#   '1930110332',
#   True,
#   None,
#   2002),
#  ('SharePoint 2010 Workflows in Action',
#   'Phil Wicklund',
#   None,
#   1,
#   '1935182714',
#   True,
#   None,
#   2011),
#  ('SharePoint 2010 Web Parts in Action',
#   'Wictor Wilén',
#   None,
#   1,
#   '1935182773',
#   False,
#   None,
#   2011),
#  ('C++ Concurrency in Action',
#   'Anthony Williams',
#   None,
#   1,
#   '1933988770',
#   False,
#   None,
#   2012),
#  ('Java Servlets by Example',
#   'Alan R. Williamson',
#   None,
#   1,
#   '188477766X',
#   True,
#   None,
#   2002),
#  ('XML Programming with VB and ASP',
#   'Mark Wilson',
#   'Tracey Wilson',
#   2,
#   '1884777872',
#   True,
#   None,
#   1999),
#  ('Oracle8i Database Administration',
#   'Noel Yuhanna',
#   None,
#   1,
#   '1884777783',
#   True,
#   None,
#   1999),
#  ('The Engaging Web',
#   'Gabe Zichermann',
#   'Chris Cunningham',
#   2,
#   '9781935182078',
#   False,
#   None,
#   None),
#  ('Enterprise OSGi In Action',
#   'Holly Cummins',
#   'Timothy Ward',
#   2,
#   '1617290130',
#   False,
#   None,
#   None),
#  ('Ext JS in Action, Second Edition',
#   'Jesus Garcia',
#   'Grgur Grisogono',
#   4,
#   '1617290327',
#   False,
#   None,
#   2014),
#  ('Android in Action, Third Edition',
#   'W. Frank Ableson',
#   'Robi Sen',
#   4,
#   '1617290505',
#   False,
#   None,
#   2011),
#  ('Arduino in Action',
#   'Martin Evans',
#   'Joshua Noble',
#   4,
#   '1617290246',
#   False,
#   None,
#   2013),
#  ('Node.js in Action',
#   'Mike Cantelon',
#   'Marc Harter',
#   5,
#   '1617290572',
#   True,
#   None,
#   2013),
#  ('Third-Party JavaScript ',
#   'Ben Vinegar',
#   'Anton Kovalyov',
#   2,
#   '1617290548',
#   False,
#   None,
#   2013),
#  ('Multimedia Computing',
#   'Matthew E. Hodges',
#   None,
#   1,
#   '020152029X',
#   False,
#   None,
#   1993),
#  ('Web Development with JavaServer Pages',
#   'Duane K. Fields',
#   'Mark A. Kolb',
#   2,
#   '1884777996',
#   False,
#   None,
#   2000),
#  ('Up to Speed with Swing',
#   'Steven J. Gutz',
#   None,
#   1,
#   '1884777643',
#   False,
#   None,
#   1998),
#  ("Manager's Guide to Open Source",
#   'Maria Winslow',
#   None,
#   1,
#   '193239429X',
#   False,
#   None,
#   2004),
#  ('Programming Web Services with Java',
#   'Ajamu A. Wesley',
#   None,
#   1,
#   '1930110421',
#   False,
#   None,
#   2002),
#  ('TCP/IP Programming for OS/2',
#   'Steven J. Gutz',
#   None,
#   1,
#   '132612496',
#   False,
#   None,
#   1996),
#  ('Implementing SAP R/3, Second Edition',
#   None,
#   None,
#   0,
#   '013889213X',
#   False,
#   None,
#   1997),
#  ('Implementing SAP R/3', None, None, 0, '1884777228', False, None, 1996),
#  ('Using C-Kermit: Communication Software',
#   None,
#   None,
#   0,
#   '1884777147',
#   False,
#   None,
#   None),
#  ('SCWCD Exam Study Kit',
#   'Hanumant Deshmukh',
#   'Jignesh Malavia',
#   2,
#   '1930110596',
#   False,
#   None,
#   2002),
#  ('Unit Testing in C++',
#   'Bruce Trask',
#   'Angel Roman',
#   2,
#   '1617290386',
#   False,
#   None,
#   None),
#  ('Big Data',
#   'Nathan Marz',
#   'James Warren',
#   2,
#   '1617290343',
#   False,
#   None,
#   None),
#  ('CoffeeScript in Action',
#   'Patrick Lee',
#   None,
#   1,
#   '1617290629',
#   False,
#   None,
#   2014),
#  ('SQL Server MVP Deep Dives, Volume 2',
#   'Kalen Delaney',
#   'Louis Davidson',
#   8,
#   '1617290475',
#   False,
#   None,
#   2011),
#  ('HTML5 in Action',
#   'Rob Crowther',
#   'Joe Lennon',
#   5,
#   '1617290491',
#   True,
#   None,
#   2014),
#  ('Java Persistence with Hibernate, Second Edition',
#   'Christian Bauer',
#   'Gavin King',
#   4,
#   '1617290459',
#   False,
#   None,
#   None),
#  ('Hadoop in Practice',
#   'Alex Holmes',
#   None,
#   1,
#   '1617290238',
#   False,
#   None,
#   2012),
#  ('HBase in Action',
#   'Nicholas Dimiduk',
#   'Amandeep Khurana',
#   2,
#   '1617290521',
#   False,
#   None,
#   2012),
#  ('Flex Mobile in Action',
#   'Jonathan Campos',
#   None,
#   1,
#   '1617290610',
#   False,
#   None,
#   2012),
#  ('HTML5 for .NET Developers',
#   'Jim Jackson',
#   'II',
#   3,
#   '1617290432',
#   False,
#   None,
#   2012),
#  ('50 Android Hacks',
#   'Carlos M. Sessa',
#   None,
#   1,
#   '1617290564',
#   False,
#   None,
#   2013),
#  ('PowerShell in Depth',
#   'Don Jones',
#   'Richard Siddaway',
#   4,
#   '1617290556',
#   False,
#   None,
#   2013),
#  ('Augmented Reality Revealed',
#   'Robert A. Rice Jr.',
#   None,
#   1,
#   '1617290165',
#   False,
#   None,
#   None),
#  ('Building Well-Structured JavaScript Applications',
#   'Julio C. Ody',
#   None,
#   1,
#   '1617290599',
#   False,
#   None,
#   None),
#  ('Linked Data',
#   'David Wood',
#   'Marsha Zaidman',
#   4,
#   '1617290394',
#   False,
#   None,
#   2013),
#  ('Mule in Action, Second Edition',
#   'David Dossot',
#   "John D'Emic",
#   4,
#   '1617290823',
#   False,
#   None,
#   2014),
#  ('Single Page Web Applications',
#   'Michael S. Mikowski',
#   'Josh C. Powell',
#   2,
#   '1617290750',
#   False,
#   None,
#   2013),
#  ('The Art of Unit Testing, Second Edition',
#   'Roy Osherove',
#   None,
#   1,
#   '1617290890',
#   False,
#   None,
#   2013),
#  ('Play for Java',
#   'Nicolas Leroux',
#   'Sietse de Kaper',
#   2,
#   '1617290904',
#   False,
#   None,
#   2014),
#  ('Hello World! Second Edition',
#   'Warren Sande',
#   'Carter Sande',
#   2,
#   '1617290920',
#   False,
#   None,
#   2013),
#  ('Dart in Action', 'Chris Buckett', None, 1, '1617290866', False, None, 2012),
#  ('Redis in Action',
#   'Josiah Carlson',
#   None,
#   1,
#   '1617290858',
#   False,
#   None,
#   2013),
#  ('Using the TI-83 Plus/TI-84 Plus',
#   'Christopher R. Mitchell',
#   None,
#   1,
#   '161729084X',
#   False,
#   None,
#   2013),
#  ('Neo4j in Action',
#   'Jonas Partner',
#   'Aleksa Vukotic',
#   4,
#   '1617290769',
#   False,
#   None,
#   None),
#  ('Programming the TI-83 Plus/TI-84 Plus',
#   'Christopher R. Mitchell',
#   None,
#   1,
#   '1617290777',
#   False,
#   None,
#   2012),
#  ('Functional Programming in Scala',
#   'Paul Chiusano',
#   'Rúnar Bjarnason',
#   2,
#   '1617290653',
#   False,
#   None,
#   None),
#  ('Play for Scala',
#   'Peter Hilton',
#   'Erik Bakker',
#   4,
#   '1617290793',
#   False,
#   None,
#   2013),
#  ('Node.js in Practice',
#   'Alex Young',
#   'Marc Harter',
#   2,
#   '1617290939',
#   False,
#   None,
#   None),
#  ('SonarQube in Action',
#   'G. Ann Campbell',
#   'Patroklos P. Papapetrou',
#   2,
#   '1617290955',
#   False,
#   None,
#   2013),
#  ('Windows Store App Development: C# and XAML',
#   'Peter M. Brown',
#   None,
#   1,
#   '1617290947',
#   False,
#   None,
#   2013),
#  ('Learn Windows IIS in a Month of Lunches',
#   'Jason C. Helmick',
#   None,
#   1,
#   '1617290971',
#   False,
#   None,
#   2013),
#  ('Mondrian in Action',
#   'William Back',
#   'Nicholas Goodman',
#   4,
#   '161729098X',
#   False,
#   None,
#   None),
#  ('RabbitMQ in Depth',
#   'Gavin M. Roy',
#   None,
#   1,
#   '1617291005',
#   False,
#   None,
#   None),
#  ('Akka in Action',
#   'Raymond Roestenburg',
#   'Rob Bakker',
#   4,
#   '1617291013',
#   False,
#   None,
#   None),
#  ('Extending jQuery',
#   'Keith B. Wood',
#   None,
#   1,
#   '161729103X',
#   False,
#   None,
#   2013),
#  ('OCA Java SE 7 Programmer I Certification Guide',
#   'Mala Gupta',
#   None,
#   1,
#   '1617291048',
#   False,
#   None,
#   2013),
#  ('Kanban in Action',
#   'Marcus Hammarberg',
#   'Joakim Sunden',
#   2,
#   '1617291056',
#   False,
#   None,
#   2014),
#  ('Solr in Action',
#   'Trey Grainger',
#   'Timothy Potter',
#   2,
#   '1617291021',
#   False,
#   None,
#   2014),
#  ('Making Sense of NoSQL',
#   'Daniel G. McCreary',
#   'Ann M. Kelly',
#   2,
#   '1617291072',
#   False,
#   None,
#   2013),
#  ('Jaguar Development with PowerBuilder 7',
#   'MIchael Barlotta',
#   None,
#   1,
#   '1884777864',
#   False,
#   None,
#   1999),
#  ('Grails in Action, Second Edition',
#   'Glen Smith',
#   'Peter Ledbrook',
#   2,
#   '1617290963',
#   False,
#   None,
#   None),
#  ('Rails 4 in Action',
#   'Ryan Bigg',
#   'Yehuda Katz',
#   4,
#   '1617291099',
#   False,
#   None,
#   None),
#  ('Learn Windows PowerShell in a Month of Lunches, Second Edition',
#   'Don Jones',
#   'Jeffery D. Hicks',
#   2,
#   '1617291080',
#   False,
#   None,
#   2012),
#  ('AOP in .NET', 'Matthew D. Groves', None, 1, '1617291145', False, None, 2013),
#  ('Learn PowerShell Toolmaking in a Month of Lunches',
#   'Don Jones',
#   'Jeffery Hicks',
#   2,
#   '1617291161',
#   False,
#   None,
#   2012),
#  ('CMIS and Apache Chemistry in Action',
#   'Florian Müller',
#   'Jay Brown',
#   3,
#   '1617291153',
#   False,
#   None,
#   None),
#  ('Action Guide (aka VB .NET)',
#   'Paul Messick',
#   None,
#   1,
#   '1930110324',
#   False,
#   None,
#   None),
#  ('Learn Active Directory Management in a Month of Lunches',
#   'Richard Siddaway',
#   None,
#   1,
#   '1617291196',
#   False,
#   None,
#   None),
#  ('Spring in Action, Fourth Edition',
#   'Craig Walls',
#   None,
#   1,
#   '161729120X',
#   False,
#   None,
#   None),
#  ('The Mikado Method',
#   'Ola Ellnestam',
#   'Daniel Brolund',
#   2,
#   '1617291218',
#   False,
#   None,
#   2014),
#  ('The Responsive Web',
#   'Matthew Carver',
#   None,
#   1,
#   '1617291242',
#   False,
#   None,
#   None),
#  ('Fast ASP.NET Websites',
#   'Dean Alan Hume',
#   None,
#   1,
#   '1617291250',
#   False,
#   None,
#   2013),
#  ('SBT in Action',
#   'Joshua Suereth',
#   'Matthew Farwell',
#   2,
#   '1617291277',
#   False,
#   None,
#   None),
#  ('PowerShell Deep Dives',
#   'Edited by Jeffery Hicks',
#   'Richard Siddaway',
#   5,
#   '1617291315',
#   False,
#   None,
#   None),
#  ('Gradle in Action',
#   'Benjamin Muschko',
#   None,
#   1,
#   '1617291307',
#   False,
#   None,
#   2014),
#  ('Scalatra in Action',
#   'Ivan Porto Carrero',
#   'Ross A. Baker',
#   6,
#   '1617291293',
#   False,
#   None,
#   None),
#  ('AngularJS in Action',
#   'Brian Ford',
#   'Lukas Ruebbelke',
#   2,
#   '1617291331',
#   False,
#   None,
#   None),
#  ('Software Development Metrics',
#   'David Nicolette',
#   None,
#   1,
#   '1617291358',
#   False,
#   None,
#   None),
#  ('F# Deep Dives',
#   'Tomas Petricek',
#   'Phillip Trelford',
#   2,
#   '1617291323',
#   False,
#   None,
#   None),
#  ('C# in Depth, Third Edition',
#   'Jon Skeet',
#   None,
#   1,
#   '161729134X',
#   False,
#   None,
#   2013),
#  ('PostGIS in Action, Second Edition',
#   'Regina Obe',
#   'Leo Hsu',
#   2,
#   '1617291390',
#   False,
#   None,
#   None),
#  ('R in Action, Second Edition',
#   'Robert Kabacoff',
#   None,
#   1,
#   '1617291382',
#   False,
#   None,
#   None),
#  ('The Joy of Clojure, Second Edition',
#   'Michael Fogus',
#   'Chris Houser',
#   2,
#   '1617291412',
#   False,
#   None,
#   2014),
#  ('iOS 7 in Action',
#   'Brendan G. Lim',
#   'Martin Conte Mac Donell',
#   2,
#   '1617291420',
#   False,
#   None,
#   2014),
#  ('Hello App Inventor!',
#   'Paula Beer',
#   'Carl Simmons',
#   2,
#   '1617291439',
#   False,
#   None,
#   None),
#  ('Ember.js in Action',
#   'Joachim Haagen Skeie',
#   None,
#   1,
#   '1617291455',
#   False,
#   None,
#   2014),
#  ('Netty in Action',
#   'Norman Maurer',
#   'Courtney Robinson',
#   2,
#   '1617291471',
#   False,
#   None,
#   None),
#  ('RavenDB in Action',
#   'Itamar Syn-Hershko',
#   None,
#   1,
#   '1617291501',
#   False,
#   None,
#   None),
#  ('OCP Java SE 7 Programmer II Certification Guide',
#   'Mala Gupta',
#   None,
#   1,
#   '161729148X',
#   False,
#   None,
#   None),
#  ('Backbone.js in Action',
#   'Samuel M. Breed',
#   'Cole Krumbholz',
#   4,
#   '1617291536',
#   False,
#   None,
#   None),
#  ('Clojure in Action, Second Edition',
#   'Amit Rathore',
#   None,
#   1,
#   '1617291528',
#   False,
#   None,
#   None),
#  ('Practical Data Science with R',
#   'Nina Zumel',
#   'John Mount',
#   2,
#   '1617291560',
#   False,
#   None,
#   2014),
#  ('Secrets of the JavaScript Ninja pBook upgrade',
#   None,
#   None,
#   0,
#   None,
#   False,
#   None,
#   None),
#  ('ArcGIS Web Development',
#   'Rene Rubalcava',
#   None,
#   1,
#   '1617291617',
#   False,
#   None,
#   None),
#  ('Elasticsearch in Action',
#   'Radu Gheorghe',
#   'Matthew Lee Hinman',
#   2,
#   '1617291625',
#   False,
#   None,
#   None),
#  ('Learn SCCM 2012 in a Month of Lunches',
#   'James Bannan',
#   None,
#   1,
#   '1617291684',
#   False,
#   None,
#   None),
#  ('Programming for Musicians and Digital Artists',
#   'Ajay Kapur',
#   'Perry Cook',
#   5,
#   '1617291706',
#   False,
#   None,
#   None),
#  ('BDD in Action', 'John F. Smart', None, 1, '161729165X', False, None, None),
#  ('Windows Phone 8 in Action',
#   'Timothy Binkley-Jones',
#   'Massimo Perga',
#   4,
#   '1617291374',
#   False,
#   None,
#   2013),
#  ('Titanium Alloy in Action',
#   'Ricardo Alcocer',
#   None,
#   1,
#   '1617291749',
#   False,
#   None,
#   None),
#  ('Giraph in Action',
#   'Claudio Martella',
#   'Roman Shaposhnik',
#   4,
#   '1617291757',
#   False,
#   None,
#   None),
#  ('The Well-Grounded Rubyist, Second Edition',
#   'David A. Black',
#   None,
#   1,
#   '1617291692',
#   False,
#   None,
#   2014),
#  ('Go in Action',
#   'Brian Ketelsen',
#   'Erik St. Martin',
#   4,
#   '1617291781',
#   False,
#   None,
#   None),
#  ("The Programmer's Guide to Apache Thrift ",
#   'Randy Abernethy',
#   None,
#   1,
#   '1617291811',
#   False,
#   None,
#   None),
#  ('Grokking Functional Programming',
#   'Aslam Khan',
#   None,
#   1,
#   '1617291838',
#   False,
#   None,
#   None),
#  ('CORS in Action', 'Monsur Hossain', None, 1, '161729182X', False, None, None),
#  ('Reactive Design Patterns',
#   'Roland Kuhn',
#   'Jamie Allen',
#   2,
#   '1617291803',
#   False,
#   None,
#   None),
#  ('Storm Applied',
#   'Sean Allen',
#   'Peter Pathirana',
#   4,
#   '1617291897',
#   False,
#   None,
#   None),
#  ('Real-World Machine Learning',
#   'Henrik Brink',
#   'Joseph Richards',
#   2,
#   '1617291927',
#   False,
#   None,
#   None),
#  ('jQuery UI in Action',
#   'Theodore J. (T.J.) VanToll III',
#   None,
#   1,
#   '1617291935',
#   False,
#   None,
#   None),
#  ('Web Components in Action',
#   'Chris Buckett',
#   None,
#   1,
#   '1617291943',
#   False,
#   None,
#   None),
#  ('JavaScript Application Design',
#   'Nicolas G. Bevacqua',
#   None,
#   1,
#   '1617291951',
#   False,
#   None,
#   None),
#  ('Git in Practice', 'Mike McQuaid', None, 1, '1617291978', False, None, None),
#  ('Impala in Action',
#   'Richard L. Saltzer',
#   'Istvan Szegedi',
#   2,
#   '1617291986',
#   False,
#   None,
#   None),
#  ('Java 8 in Action',
#   'Raoul-Gabriel Urma',
#   'Mario Fusco',
#   4,
#   '1617291994',
#   False,
#   None,
#   None),
#  ('Elixir in Action', 'Saša Juric´', None, 1, '161729201X', False, None, None),
#  ('MongoDB in Action, Second Edition',
#   'Kyle Banker',
#   'Peter Bakkum',
#   6,
#   '1617291609',
#   False,
#   None,
#   None),
#  ('Getting MEAN with Mongo, Express, Angular, and Node',
#   'Simon Holmes',
#   None,
#   1,
#   '1617292036',
#   False,
#   None,
#   None),
#  ('jQuery in Action, Third Edition',
#   'Bear Bibeault',
#   'Yehuda Katz',
#   4,
#   '1617292079',
#   False,
#   None,
#   None),
#  ('D3.js in Action', 'Elijah Meeks', None, 1, '1617292117', False, None, None),
#  ('Learn SQL Server Administration in a Month of Lunches',
#   'Don Jones',
#   None,
#   1,
#   '1617292133',
#   False,
#   None,
#   2014),
#  ('Geoprocessing with Python',
#   'Chris Garrard',
#   None,
#   1,
#   '1617292141',
#   False,
#   None,
#   None),
#  ('Barcodes with iOS',
#   'Oliver Drobnik',
#   None,
#   1,
#   '161729215X',
#   False,
#   None,
#   None),
#  ('Chef in Action',
#   'Dimitri Aivaliotis',
#   None,
#   1,
#   '1617292214',
#   False,
#   None,
#   None),
#  ('Hadoop in Practice, Second Edition',
#   'Alex Holmes',
#   None,
#   1,
#   '1617292222',
#   False,
#   None,
#   None),
#  ('Oculus Rift in Action',
#   'Bradley Austin Davis',
#   'Karen Bryla',
#   4,
#   '1617292192',
#   False,
#   None,
#   None),
#  ('OpenStack in Action',
#   'Cody Bumgardner',
#   None,
#   1,
#   '1617292168',
#   False,
#   None,
#   None),
#  ('PowerShell in Depth, Second Edition',
#   'Don Jones',
#   'Jeffery Hicks',
#   4,
#   '1617292184',
#   False,
#   None,
#   None),
#  ('Practical Probabilistic Programming',
#   'Avi Pfeffer',
#   None,
#   1,
#   '1617292338',
#   False,
#   None,
#   None),
#  ('Unity in Action',
#   'Joseph Hocking',
#   None,
#   1,
#   '161729232X',
#   False,
#   None,
#   None),
#  ('Express.js in Action',
#   'Evan M. Hahn',
#   None,
#   1,
#   '1617292427',
#   False,
#   None,
#   None),
#  ('Learn Git in a Month of Lunches',
#   'Rick Umali',
#   None,
#   1,
#   '1617292419',
#   False,
#   None,
#   None),
#  ('Understanding SPAs',
#   'Emmit A. Scott',
#   'Jr.',
#   2,
#   '1617292435',
#   False,
#   None,
#   None),
#  ('XSLT Quickly', None, None, 0, '1930110111', False, None, 2001),
#  ('Windows Forms Programming with C#',
#   None,
#   None,
#   0,
#   '1930110286',
#   True,
#   None,
#   2002),
#  ('Windows Forms in Action', None, None, 0, '1932394656', True, None, 2006),
#  ('Event Processing in Action', None, None, 0, '1935182218', False, None, 2010),
#  ('The Well-Grounded Java Developer',
#   None,
#   None,
#   0,
#   '1617290068',
#   True,
#   None,
#   2012),
#  ('Objective-C Fundamentals', None, None, 0, '1935182536', False, None, 2011),
#  ('ADO.NET Programming', None, None, 0, '1930110294', True, None, 2002),
#  ('WPF in Action with Visual Studio 2008',
#   None,
#   None,
#   0,
#   '1933988223',
#   False,
#   None,
#   2008),
#  ('Location-Aware Applications',
#   None,
#   None,
#   0,
#   '1935182331',
#   False,
#   None,
#   2011),
#  ('Web Development with JavaServer Pages, Second Edition',
#   None,
#   None,
#   0,
#   '193011012X',
#   True,
#   None,
#   2001),
#  ('IntelliJ IDEA in Action', None, None, 0, '1932394443', False, None, 2006),
#  ('Spring Integration in Action',
#   None,
#   None,
#   0,
#   '1935182439',
#   False,
#   None,
#   2012),
#  ('The Joy of Clojure', None, None, 0, '1935182641', True, None, 2011),
#  ('Dynamic WAP Application Development',
#   None,
#   None,
#   0,
#   '1930110081',
#   False,
#   None,
#   2002),
#  ('IronPython in Action', None, None, 0, '1933988339', False, None, 2009),
#  ('Art of Java Web Development',
#   None,
#   None,
#   0,
#   '1932394060',
#   False,
#   None,
#   2003),
#  ('Java Reflection in Action', None, None, 0, '1932394184', False, None, 2004),
#  ('Programming Windows Server 2003',
#   None,
#   None,
#   0,
#   '1930110987',
#   False,
#   None,
#   2003),
#  ('Struts Recipes', None, None, 0, '1932394249', False, None, 2004),
#  ('Hello! iOS Development', None, None, 0, '1935182986', False, None, 2013),
#  ('Jess in Action', None, None, 0, '1930110898', False, None, 2003),
#  ('Remote LAN Access', None, None, 0, '134944518', False, None, 1996),
#  ('J2EE and XML Development', None, None, 0, '1930110308', False, None, 2002),
#  ('Eclipse in Action', None, None, 0, '1930110960', False, None, 2003),
#  ('ASP.NET AJAX in Action', None, None, 0, '1933988142', False, None, 2007),
#  ('Ext JS in Action', None, None, 0, '1935182110', True, None, 2010),
#  ('Sencha Touch in Action', None, None, 0, '1617290378', False, None, 2013),
#  ('DSLs in Action', None, None, 0, '1935182455', False, None, 2010),
#  ('Database Programming for Handheld Devices',
#   None,
#   None,
#   0,
#   '1884777856',
#   False,
#   None,
#   2000),
#  ('Jakarta Commons Online Bookshelf',
#   None,
#   None,
#   0,
#   '1932394524',
#   False,
#   None,
#   2005),
#  ('Browsing with HttpClient',
#   None,
#   None,
#   0,
#   '1932394524a-e',
#   False,
#   None,
#   2005),
#  ('Codec: Encoders and Decoders',
#   None,
#   None,
#   0,
#   '1932394524j-e',
#   False,
#   None,
#   2005)]

# %% [markdown]
# 1. Reason. I wrote a program to extract specific book data (title of book, name of author, etc). To do this I created a list called rows, then specified details of each book data to information specifications using the try/except method, and ended by creating a tuple with the book data, appending it to the list named rows.

# %% [markdown]
# 1. Conclusion. Utilized pretty print to acquire the information of the desired extracted information.

# %% [markdown]
# 2. Save the content of `rows` in a SQL-like table using `sqlite3`, and choose the appropriate column types. <span style="color:red" float:right>[2 point]</span>
#
#   As your column names use the following:
#
#   - `title`
#   - `author_1`
#   - `author_2`
#   - `num_authors`
#   - `isbn`
#   - `has_data`
#   - `desc_len`
#   - `year_published`

# %%
import sqlite3

# Creating a connection to an in-memory SQLite database as shown in class.
connection = sqlite3.connect(':memory:') 
cursor = connection.cursor()

cursor.execute('''CREATE TABLE books
             (title text, author_1 text, author_2 text, num_authors int, isbn text, has_data text, desc_len text, year_published int)''')

# Insert the rows list into the new table
cursor.executemany('INSERT INTO books VALUES (?,?,?,?,?,?,?,?)', rows)

# Save the changes
connection.commit()

# %% [markdown]
# 2. Reason. Utilzed sqlite 3 to save the content of the rows with the given column types.

# %% [markdown]
# 2. Conclusion. Inserted the rows list into the new table with specified columns and saved the changes.

# %% [markdown]
# 3. Write a SQL query against the table to show all books that (1) contain the word "data" and (2) have more than 3 authors. Store the result of the query in an object called `books_table`, then close the connection. <span style="color:red" float:right>[2 point]</span>

# %%
# Query books with the word "data" in the description and more than 3 authors.
books_table = cursor.execute('SELECT * FROM books WHERE has_data = 1 AND num_authors > 3').fetchall()
print(books_table)

# Close connection to the database.
connection.close()
# Out:
# [('Flex 4 in Action', 'Tariq Ahmed', 'Dan Orlando', 4, '1935182420', '1', None, 2010), ('Spring Dynamic Modules in Action', 'Arnaud Cogoluegnes', 'Thierry Templier', 4, '1935182307', '1', None, 2010), ('Android in Practice', 'Charlie Collins', 'Michael D. Galpin', 4, '1935182927', '1', None, 2011), ('Portlets and Apache Portals', 'Stefan Hepper', 'Peter Fischer', 5, None, '1', None, 2005), ('Struts in Action', 'Ted N. Husted', 'Cedric Dumoulin', 4, '1932394249', '1', None, 2002), ('Taming Text', 'Grant S. Ingersoll', 'Thomas S. Morton', 4, '193398838X', '1', None, 2012), ('Groovy in Action', 'Dierk Koenig with Andrew Glover', 'Paul King', 4, '1932394842', '1', None, 2007), ('Groovy in Action, Second Edition', 'Dierk König', 'Guillaume Laforge', 8, '1935182447', '1', None, None), ('NHibernate in Action', 'Pierre Henri Kuate', 'Tobin Harris', 5, '1932394923', '1', None, 2009), ('Tuscany SCA in Action', 'Simon Laws', 'Mark Combellack', 5, '1933988894', '1', None, 2011), ('Entity Framework 4 in Action', 'Stefano Mostarda', 'Marco De Sanctis', 4, '1935182188', '1', None, 2011), ('SQL Server MVP Deep Dives', 'Contributions from 53 SQL Server MVPs', 'Edited by Paul Nielsen', 8, '1935182048', '1', None, 2009), ('SQL Server MVP Deep Dives', 'Contributions from 53 SQL Server MVPs; Edited by Paul Nielsen', 'Kalen Delaney', 7, '9781935182047', '1', None, 2009), ('ASP.NET MVC 2 in Action', 'Jeffrey Palermo', 'Ben Scheirman', 6, '193518279X', '1', None, 2010), ('ASP.NET MVC 4 in Action', 'Jeffrey Palermo', 'Jimmy Bogard', 6, '1617290416', '1', None, 2012), ('JUnit in Action, Second Edition', 'Petar Tahchiev', 'Felipe Leme', 5, '1935182021', '1', None, 2010), ('Node.js in Action', 'Mike Cantelon', 'Marc Harter', 5, '1617290572', '1', None, 2013), ('HTML5 in Action', 'Rob Crowther', 'Joe Lennon', 5, '1617290491', '1', None, 2014)]

# %% [markdown]
# 3. Reason. Created an SQL query against the table containing the word "data" and over three authors.

# %% [markdown]
# 3. Conclusion. Stored the query result in books_table and closed the connection to the database.

# %% [markdown]
# SQL tables are not the only way, and definitely not the most straightforward way to store and manipulate data in Python. A format that's more popular with data scientist is to use the `pandas` library to create a `DataFrame`. This library has a lot of functionality that makes it easy to run the common tasks data scientists do with data.
#
# 4. Read the data from the above query into a `DataFrame` and call it `books_df`. HINT: Use `pd.DataFrame` and specify meaningful column names to use for the columns. <span style="color:red" float:right>[1 point]</span>

# %%
import pandas as pd

# Create a list of column names for the dataframe
columns = ['title', 'author_1', 'author_2', 'num_authors', 'isbn', 'has_data', 'desc_len', 'year_published']

# Load the books_table subject into a dataframe with the above column names
books_df = pd.DataFrame(data = books_table, columns = columns)

# Change the data type of the has_data column back to boolean
books_df['has_data'] = books_df['has_data'].astype('bool')

# Change the data type of the year published column to an integer vice float as default
books_df['year_published'] = books_df['year_published'].astype('Int64')

books_df
# Out:
#                                title  \
# 0                   Flex 4 in Action
# 1   Spring Dynamic Modules in Action
# 2                Android in Practice
# 3        Portlets and Apache Portals
# 4                   Struts in Action
# 5                        Taming Text
# 6                   Groovy in Action
# 7   Groovy in Action, Second Edition
# 8               NHibernate in Action
# 9              Tuscany SCA in Action
# 10      Entity Framework 4 in Action
# 11         SQL Server MVP Deep Dives
# 12         SQL Server MVP Deep Dives
# 13           ASP.NET MVC 2 in Action
# 14           ASP.NET MVC 4 in Action
# 15   JUnit in Action, Second Edition
# 16                 Node.js in Action
# 17                   HTML5 in Action
#
#                                              author_1                author_2  \
# 0                                         Tariq Ahmed             Dan Orlando
# 1                                  Arnaud Cogoluegnes        Thierry Templier
# 2                                     Charlie Collins       Michael D. Galpin
# 3                                       Stefan Hepper           Peter Fischer
# 4                                       Ted N. Husted         Cedric Dumoulin
# 5                                  Grant S. Ingersoll        Thomas S. Morton
# 6                     Dierk Koenig with Andrew Glover               Paul King
# 7                                         Dierk König       Guillaume Laforge
# 8                                  Pierre Henri Kuate            Tobin Harris
# 9                                          Simon Laws         Mark Combellack
# 10                                   Stefano Mostarda        Marco De Sanctis
# 11              Contributions from 53 SQL Server MVPs  Edited by Paul Nielsen
# 12  Contributions from 53 SQL Server MVPs; Edited ...           Kalen Delaney
# 13                                    Jeffrey Palermo           Ben Scheirman
# 14                                    Jeffrey Palermo            Jimmy Bogard
# 15                                     Petar Tahchiev             Felipe Leme
# 16                                      Mike Cantelon             Marc Harter
# 17                                       Rob Crowther              Joe Lennon
#
#     num_authors           isbn  has_data desc_len  year_published
# 0             4     1935182420      True     None            2010
# 1             4     1935182307      True     None            2010
# 2             4     1935182927      True     None            2011
# 3             5           None      True     None            2005
# 4             4     1932394249      True     None            2002
# 5             4     193398838X      True     None            2012
# 6             4     1932394842      True     None            2007
# 7             8     1935182447      True     None            <NA>
# 8             5     1932394923      True     None            2009
# 9             5     1933988894      True     None            2011
# 10            4     1935182188      True     None            2011
# 11            8     1935182048      True     None            2009
# 12            7  9781935182047      True     None            2009
# 13            6     193518279X      True     None            2010
# 14            6     1617290416      True     None            2012
# 15            5     1935182021      True     None            2010
# 16            5     1617290572      True     None            2013
# 17            5     1617290491      True     None            2014

# %% [markdown]
# 4. Reason. Read the data from the SQL query into a dataframe using pd.dataframe and named it books_df with specific column names for the columns.

# %% [markdown]
# 4. Conclusion. Created a dataframe named books_df and displayed it showing columns with specific information.

# %% [markdown]
# 5. Display the first few columns of a `DataFrame` by calling its `head` method. <span style="color:red" float:right>[1 point]</span>

# %%
# Displaying the first five rows of the dataframe using .head
books_df.head()
# Out:
#                               title            author_1           author_2  \
# 0                  Flex 4 in Action         Tariq Ahmed        Dan Orlando
# 1  Spring Dynamic Modules in Action  Arnaud Cogoluegnes   Thierry Templier
# 2               Android in Practice     Charlie Collins  Michael D. Galpin
# 3       Portlets and Apache Portals       Stefan Hepper      Peter Fischer
# 4                  Struts in Action       Ted N. Husted    Cedric Dumoulin
#
#    num_authors        isbn  has_data desc_len  year_published
# 0            4  1935182420      True     None            2010
# 1            4  1935182307      True     None            2010
# 2            4  1935182927      True     None            2011
# 3            5        None      True     None            2005
# 4            4  1932394249      True     None            2002

# %%
books_df.dtypes
# Out:
# title             object
# author_1          object
# author_2          object
# num_authors        int64
# isbn              object
# has_data            bool
# desc_len          object
# year_published     Int64
# dtype: object

# %% [markdown]
# 5. Reason. To display the first five rows of the dataframe named books_df using the .head method.

# %% [markdown]
# 5. Conclusion. Displayed the first five rows of the datagrame named books_df.

# %% [markdown]
# Remember how earlier we said that a `DataFrame` is built on top of `numpy` arrays? Another way of saying it is that a `DataFrame` is an **abstraction** on top of `numpy` arrays: i.e. a `DataFrame` is a more **high-level** object than a `numpy` array.
#
# 6. Call the `values` attribute of your `DataFrame` to convert it into a numpy array and display the first 3 elements of the array. <span style="color:red" float:right>[1 point]</span>

# %%
import numpy as np

# Create a numpy array from the dataframe's values method.
np_array = books_df.values

# Display the first three elements of the array.
print(np_array[:3])
# Out:
# [['Flex 4 in Action' 'Tariq Ahmed' 'Dan Orlando' 4 '1935182420' True None
#   2010]
#  ['Spring Dynamic Modules in Action' 'Arnaud Cogoluegnes'
#   'Thierry Templier' 4 '1935182307' True None 2010]
#  ['Android in Practice' 'Charlie Collins' 'Michael D. Galpin' 4
#   '1935182927' True None 2011]]

# %% [markdown]
# 6. Reason. To call the values attribute of the books_df dataframe and convert it into a numpy array. Then display the first three elements of that array.

# %% [markdown]
# 6. Conclusion. Created a numpy array from the dataframe's values method and displayed the first three elements of the array using the print function. Displayed is the first three rows of books_df.

# %% [markdown]
# Now you can judge which object is more "user-friendly". That's one of the things that abstractions allow us to do: build more user-friendly (abstract) objects from less user-friendly (but more fundamental) objects.
#
# # End of assignment
